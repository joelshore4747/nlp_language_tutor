# %%
from nlp_tutor.languages import Lang
from nlp_tutor.corpora import load_lm_corpus
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from nlp_tutor.languages import Lang
#       2 from nlp_tutor.corpora import load_lm_corpus
#
# ModuleNotFoundError: No module named 'nlp_tutor'

# %%
en_sents = load_lm_corpus(Lang.EN)
es_sents = load_lm_corpus(Lang.ES)
